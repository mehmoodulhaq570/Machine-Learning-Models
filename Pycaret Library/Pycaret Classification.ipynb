# %%
import pandas as pd
from pycaret.classification import * # type: ignore

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('C://Users//mehmo//Downloads//Learning Course//Machine Learnig Course//20 Pycaret Modelling//heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
cat_features = ['age', 'sex', 'cp', 'fbs', 'slp','restecg', 'exng', 'caa', 'thall']

# %%
experiment = setup(df, target='output', categorical_features=cat_features)
# Out:
# ...
# <style type="text/css">
# #T_de886_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_de886">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de886_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_de886_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de886_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de886_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_de886_row0_col1" class="data row0 col1" >2628</td>
#     </tr>
#     <tr>
#       <th id="T_de886_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de886_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_de886_row1_col1" class="data row1 col1" >output</td>
#     </tr>
#     <tr>
#       <th id="T_de886_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_8dd2b th {
#   text-align: left;
# }
# ...

# %%
predict_model(best_model, df.tail())
# Out:
# <style type="text/css">
# </style>
# <table id="T_40208">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40208_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_40208_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_40208_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_40208_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_40208_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_40208_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_40208_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_40208_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40208_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40208_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %%
save_model(best_model, model_name='ridge-model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['trtbps', 'chol', 'thalachh',
#                                               'oldpeak'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age'...
# ...

# %%
model = load_model('ridge-model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
lr = create_model('lr') # plotting a model 
plot_model(lr)
# Out:
# <style type="text/css">
# #T_77799_row10_col0, #T_77799_row10_col1, #T_77799_row10_col2, #T_77799_row10_col3, #T_77799_row10_col4, #T_77799_row10_col5, #T_77799_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_77799">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77799_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_77799_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_77799_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_77799_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_77799_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_77799_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_77799_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
knn = create_model('knn') # type: ignore
# Out:
# <style type="text/css">
# #T_88c90_row10_col0, #T_88c90_row10_col1, #T_88c90_row10_col2, #T_88c90_row10_col3, #T_88c90_row10_col4, #T_88c90_row10_col5, #T_88c90_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_88c90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88c90_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_88c90_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_88c90_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_88c90_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_88c90_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_88c90_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_88c90_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(knn, plot = 'confusion_matrix')
