# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("carprices.csv")
df.head(5)
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %% [markdown]
# ## Mileage Vs Sell Price

# %%
# %matplotlib inline
plt.scatter(df['Mileage'], df['Sell Price($)'])

# %% [markdown]
# ## Age(yrs) Vs Sell Price

# %%
# %matplotlib inline
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
# This will pick any random samples for the datasets and will execute the test_train_split on them. Every time you run this the samples will be changes
# For a model you want your samples to remain the same, you need to add random_state = 10 after test_size, 10 means 10 number of samples

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 4     46000         4
# 10    83000         7
# 0     69000         6
# 5     59000         5
# 19    52000         5
# 1     35000         3
# 18    87600         8
# 15    25400         3
# 8     91000         8
# 7     72000         6
# 14    82450         7
# 2     57000         5
# 11    79000         7
# 17    69000         5
# 6     52000         5

# %%
# Data being used for training the model
len(X_train)
# Out:
# 16

# %%
 len(y_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([22474.98804633, 25417.42486259, 25427.34737214, 36949.71748934])

# %%
y_test
# Out:
# 9     22000
# 13    27500
# 12    26000
# 16    35500
# Name: Sell Price($), dtype: int64

# %%
accuracy  = model.score(X_test, y_test)
# Out:
# 0.9273522630835433
